# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from pylab import *
import scipy.stats as stats
import pylab



#mpl.style.available
#mpl.style.use('ggplot') 
# %matplotlib inline

# %% [markdown]
# ##Description
# 9 variables for all 16,924 10 mile participants in the 2012 Cherry Blossom Run.
#
# ##Format
#  The run10 (2012 data) summarizes 16,924 observations on 9 variables.
#
# place: Finishing position. Separate positions are provided for each gender.
#
# time: The total run time. For run10, this is equivalent to netTime. netTime The run time from the start line to the finish line.
#
# pace: The listed pace for each runner.
#
# age: Age.
#
# gender: Gender.
#
# location: Hometown city.
#
# state: Hometown state.
#
# divPlace: Division place, also broken up by gender. (Division is running devision by age.)
#
# divTot: Total number of people in the division (again, also split by gender).

# %% [markdown]
# Import as a dataframe run10.txt

# %%
df=pd.read_table("/home/vagrant/notebooks/training/Stats/run10.txt")

# %% [markdown]
# Explore the first lines of the data

# %%
df.head()
# Out:
#    place    time    pace  age gender             location state  divPlace  \
# 0   4494   92.25   9.225   38      M  Chesapeake Beach MD    MD       690
# 1   6298  106.35  10.635   33      M        Washington DC    DC      1322
# 2   2502   89.33   8.933   55      F            McLean VA    VA        37
# 3   8176  113.50  11.350   24      F        Alexandria VA    VA       878
# 4   3413   86.52   8.652   54      M     San Francisco CA    CA       213
#
#    divTot
# 0    1093
# 1    1490
# 2     236
# 3     974
# 4     483

# %% [markdown]
# Get a summary of the data

# %%
df.describe()
# Out:
#               place          time          pace           age      divPlace  \
# count  16924.000000  16924.000000  16924.000000  16923.000000  16923.000000
# mean    4326.802529     94.519192      9.451919     35.521066    720.663417
# std     2600.939715     15.927157      1.592716     10.163366    626.274890
# min        1.000000     45.250000      4.525000      9.000000      1.000000
# 25%     2116.000000     83.727500      8.372750     28.000000    228.000000
# 50%     4231.500000     94.030000      9.403000     33.000000    549.000000
# 75%     6347.000000    104.455000     10.445500     41.000000   1031.500000
# max     9732.000000    170.970000     17.097000     89.000000   2782.000000
#
#              divTot
# count  16923.000000
# mean    1440.326833
# std      811.168890
# min        1.000000
# 25%      931.000000
# 50%     1367.000000
# 75%     2228.000000
# max     2782.000000

# %% [markdown]
# Use pd.scatter_matrix(dataframe) on the dataframe to get an overview of the relationships between the variables.
# If you need to enlarge the plot add the argument figsize=(15,15) in pd.scatter_matrix.

# %%
pd.scatter_matrix(df, figsize=(15,15))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7f5ed798e1d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7945cd0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed78ffad0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed783e350>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed77c4110>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed77ac410>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f5ed76bb2d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed768add0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed76251d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed75e0350>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7512a90>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7497850>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f5ed73ff8d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7390850>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed72f82d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed727c3d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7236550>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed71e6f50>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f5ed716dd10>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed70d4d90>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed7063d10>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6fbf790>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6f51a50>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6f0dbd0>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f5ed6e4a450>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6dcf210>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6d959d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6d25950>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6d59810>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6c0f750>],
#        [<matplotlib.axes.AxesSubplot object at 0x7f5ed6b966d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6afded0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6a81c90>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed69f43d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6978f10>,
#         <matplotlib.axes.AxesSubplot object at 0x7f5ed6a2df10>]], dtype=object)

# %% [markdown]
# Study the relationship between the variables.

# %% [markdown]
# Use pd.scatter_matrix('Variable') to get an overview of the relationships between time,pace and age.

# %% [markdown]
# Study the graph and comment on the relations of the variables.

# %% [markdown]
# # Comparison of different groups.

# %% [markdown]
# Group the database by gender. In oder to group data use .groupby('Variable')

# %% [markdown]
# Get a summary of the grouped data.

# %% [markdown]
# Comment on the graph that is produced by following code and give an appropriate name in plt.legend()

# %% [markdown]
# Produce a histogramm of time variable for the grouped data

# %% [markdown]
# Produce a histogramm for the grouped data and overimpose the fitted densities.

# %% [markdown]
# Check graphically, if the running times of men, follow a normal distribution.
